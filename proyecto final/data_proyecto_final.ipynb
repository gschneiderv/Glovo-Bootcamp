# %%
import pandas as pd
import numpy as np

# %%
# Importamos el dataset de los datos de Airbnb
df = pd.read_csv("airbnb-listings.csv", delimiter=";")
df.head()
# Out:
#          ID                            Listing Url       Scrape ID  \
# 0  15141125  https://www.airbnb.com/rooms/15141125  20170407214119
# 1   9470166   https://www.airbnb.com/rooms/9470166  20170407214119
# 2  17444981  https://www.airbnb.com/rooms/17444981  20170407214119
# 3   3284565   https://www.airbnb.com/rooms/3284565  20170407214119
# 4    499911    https://www.airbnb.com/rooms/499911  20170407214119
#
#   Last Scraped                                 Name  \
# 0   2017-04-08           Panoramic charming studio!
# 1   2017-04-08  Comfortable penthouse in the center
# 2   2017-04-08         Cosy Apartment SOL/LA LATINA
# 3   2017-04-08        Alquiler Estudio Nuevo Madrid
# 4   2017-04-08  2 bedroom apartment downtown Madrid
#
#                                              Summary  \
# 0  Charming bright and cosy studio in "El Rastro"...
# 1  In the center, recently remodeled, comfortable...
# 2  Nice apartment near Sol and La Latina. Perfect...
# 3  Alquilo estudio en el centro de Madrid , total...
# 4                                                NaN
#
#                                                Space  \
# 0  It's a bright and cosy studio located in the h...
# 1  Quiet and comfortable space where you can rela...
# 2  Is a really cosy apartment with the best locat...
# 3                                                NaN
# 4  Bright and airy apartment in Central Madrid re...
#
#                                          Description Experiences Offered  \
# 0  Charming bright and cosy studio in "El Rastro"...                none
# 1  In the center, recently remodeled, comfortable...                none
# 2  Nice apartment near Sol and La Latina. Perfect...                none
# 3  Alquilo estudio en el centro de Madrid , total...                none
# 4  Bright and airy apartment in Central Madrid re...                none
#
#                                Neighborhood Overview  ...  \
# 0  The studio is located in the remarkable neighb...  ...
# 1  It belongs to the district center of Madrid wh...  ...
# 2  La Latina is well known by El Rastro, the most...  ...
# 3                                                NaN  ...
# 4                                                NaN  ...
#
#   Review Scores Communication Review Scores Location Review Scores Value  \
# 0                        10.0                   10.0                10.0
# 1                         9.0                    9.0                 8.0
# 2                        10.0                   10.0                10.0
# 3                        10.0                    9.0                 9.0
# 4                        10.0                   10.0                10.0
#
#   License Jurisdiction Names Cancellation Policy  \
# 0     NaN                NaN            moderate
# 1     NaN                NaN              strict
# 2     NaN                NaN            moderate
# 3     NaN                NaN              strict
# 4     NaN                NaN              strict
#
#   Calculated host listings count Reviews per Month  \
# 0                            2.0              5.11
# 1                           13.0              5.88
# 2                            1.0              6.18
# 3                            3.0              0.19
# 4                            1.0              1.39
#
#                                Geolocation  \
# 0   40.40745268477803, -3.7079954754432634
# 1    40.40831556101927, -3.705006385704201
# 2  40.413722014584295, -3.7068231186536718
# 3  40.411263372718054, -3.6973054373712886
# 4    40.41255625665078, -3.701155364799422
#
#                                             Features
# 0  Host Is Superhost,Host Has Profile Pic,Host Id...
# 1  Host Has Profile Pic,Host Identity Verified,Re...
# 2  Host Has Profile Pic,Host Identity Verified,Re...
# 3  Host Has Profile Pic,Host Identity Verified,Is...
# 4  Host Is Superhost,Host Has Profile Pic,Host Id...
#
# [5 rows x 89 columns]

# %%
len(df)
# Out:
# 14780

# %%
df.columns
len(df.columns)
# Out:
# 89

# %%
#seleccionamos las columnas que nos servirán para realizar el análisis
df_madrid = df.filter(["Host Total Listing", "Street", "Neighbourhood Group Cleansed","City", "State", "Zipcode", "Smart Location","Country Code","Latitude", "Longitude", "Property Type", "Room Type","Accommodates", "Bathrooms", "Bedrooms", "Beds", "Bed Type", "Amenities", "Price", "Security Deposit", "Cleaning Fee", "Guests Included", "Extra People", "Minimum Nights", "Maximum Nights", "Number of Reviews", "Review Scores Rating", "Cancellation Policy", "Reviews per Month"],axis=1)

# %%
df_madrid.head()
# Out:
#                                               Street  \
# 0           Madrid, Comunidad de Madrid 28005, Spain
# 1           Madrid, Comunidad de Madrid 28012, Spain
# 2           Madrid, Comunidad de Madrid 28012, Spain
# 3  Embajadores, Madrid, Community of Madrid 28012...
# 4  Embajadores, Madrid, Comunidad de Madrid 28012...
#
#   Neighbourhood Group Cleansed    City                State Zipcode  \
# 0                       Centro  Madrid  Comunidad de Madrid   28005
# 1                       Centro  Madrid  Comunidad de Madrid   28012
# 2                       Centro  Madrid  Comunidad de Madrid   28012
# 3                       Centro  Madrid  Community of Madrid   28012
# 4                       Centro  Madrid  Comunidad de Madrid   28012
#
#   Smart Location Country Code   Latitude  Longitude Property Type  ...  \
# 0  Madrid, Spain           ES  40.407453  -3.707995          Loft  ...
# 1  Madrid, Spain           ES  40.408316  -3.705006     Apartment  ...
# 2  Madrid, Spain           ES  40.413722  -3.706823     Apartment  ...
# 3  Madrid, Spain           ES  40.411263  -3.697305     Apartment  ...
# 4  Madrid, Spain           ES  40.412556  -3.701155     Apartment  ...
#
#   Security Deposit  Cleaning Fee  Guests Included  Extra People  \
# 0            100.0          20.0                2            15
# 1            250.0          15.0                2            25
# 2              NaN          25.0                1             0
# 3            200.0          25.0                1            20
# 4            200.0          60.0                4             0
#
#    Minimum Nights Maximum Nights Number of Reviews  Review Scores Rating  \
# 0               2           1125                30                  96.0
# 1               1           1125                97                  81.0
# 2               1           1125                 7                  89.0
# 3               7           1125                 6                  93.0
# 4               4           1125                72                  97.0
#
#    Cancellation Policy  Reviews per Month
# 0             moderate               5.11
# 1               strict               5.88
# 2             moderate               6.18
# 3               strict               0.19
# 4               strict               1.39
#
# [5 rows x 28 columns]

# %%
#eliminamos las filas que NO tengan "City==Madrid and City==Delicias-Madrid", así me solo quedan las correspondientes a madrid
#faltar ver como incluir las palabras "mal escritas",normalizar estos datos

df_airbnb_madrid = df_madrid[df_madrid["City"] == "Madrid"]

# %%
df_airbnb_madrid.head(150)
# Out:
#                                                 Street  \
# 0             Madrid, Comunidad de Madrid 28005, Spain
# 1             Madrid, Comunidad de Madrid 28012, Spain
# 2             Madrid, Comunidad de Madrid 28012, Spain
# 3    Embajadores, Madrid, Community of Madrid 28012...
# 4    Embajadores, Madrid, Comunidad de Madrid 28012...
# ..                                                 ...
# 151  Acacias, Madrid, Comunidad de Madrid 28005, Spain
# 152  La Chopera, Madrid, Comunidad de Madrid 28045,...
# 153  La Chopera, Madrid, Community of Madrid 28045,...
# 154           Madrid, Community of Madrid 28045, Spain
# 155  La Chopera, Madrid, Comunidad de Madrid 28045,...
#
#     Neighbourhood Group Cleansed    City                State Zipcode  \
# 0                         Centro  Madrid  Comunidad de Madrid   28005
# 1                         Centro  Madrid  Comunidad de Madrid   28012
# 2                         Centro  Madrid  Comunidad de Madrid   28012
# 3                         Centro  Madrid  Community of Madrid   28012
# 4                         Centro  Madrid  Comunidad de Madrid   28012
# ..                           ...     ...                  ...     ...
# 151                   Arganzuela  Madrid  Comunidad de Madrid   28005
# 152                   Arganzuela  Madrid  Comunidad de Madrid   28045
# 153                   Arganzuela  Madrid  Community of Madrid   28045
# 154                   Arganzuela  Madrid  Community of Madrid   28045
# 155                   Arganzuela  Madrid  Comunidad de Madrid   28045
#
#     Smart Location Country Code   Latitude  Longitude Property Type  ...  \
# 0    Madrid, Spain           ES  40.407453  -3.707995          Loft  ...
# 1    Madrid, Spain           ES  40.408316  -3.705006     Apartment  ...
# 2    Madrid, Spain           ES  40.413722  -3.706823     Apartment  ...
# 3    Madrid, Spain           ES  40.411263  -3.697305     Apartment  ...
# 4    Madrid, Spain           ES  40.412556  -3.701155     Apartment  ...
# ..             ...          ...        ...        ...           ...  ...
# 151  Madrid, Spain           ES  40.402489  -3.707083     Apartment  ...
# 152  Madrid, Spain           ES  40.390912  -3.696005     Apartment  ...
# 153  Madrid, Spain           ES  40.396749  -3.698465     Apartment  ...
# 154  Madrid, Spain           ES  40.393151  -3.701239     Apartment  ...
# 155  Madrid, Spain           ES  40.394056  -3.700255     Apartment  ...
#
#     Security Deposit  Cleaning Fee  Guests Included  Extra People  \
# 0              100.0          20.0                2            15
# 1              250.0          15.0                2            25
# 2                NaN          25.0                1             0
# 3              200.0          25.0                1            20
# 4              200.0          60.0                4             0
# ..               ...           ...              ...           ...
# 151            200.0          40.0                6            20
# 152              NaN           NaN                1            10
# 153              NaN           NaN                1            30
# 154              NaN           NaN                1             0
# 155              NaN          10.0                1            15
#
#      Minimum Nights Maximum Nights Number of Reviews  Review Scores Rating  \
# 0                 2           1125                30                  96.0
# 1                 1           1125                97                  81.0
# 2                 1           1125                 7                  89.0
# 3                 7           1125                 6                  93.0
# 4                 4           1125                72                  97.0
# ..              ...            ...               ...                   ...
# 151               7           1125                 5                  96.0
# 152               1           1125                 7                  87.0
# 153               2           1125                16                  96.0
# 154               1              4                 0                   NaN
# 155               1           1125                29                  91.0
#
#      Cancellation Policy  Reviews per Month
# 0               moderate               5.11
# 1                 strict               5.88
# 2               moderate               6.18
# 3                 strict               0.19
# 4                 strict               1.39
# ..                   ...                ...
# 151               strict               0.61
# 152             flexible               0.97
# 153               strict               0.44
# 154             flexible                NaN
# 155             moderate               2.11
#
# [150 rows x 28 columns]

# %%
different_city= set(df_madrid["City"].sort_values(ascending=False))

# %%
print(different_city)
# Out:
# {'San Lázaro', nan, 'Tsim Sha Tsui', 'Madid', 'Darlinghurst', 'Dorroughby', 'La Elipa', 'Venice', 'Delicias', 'Caimari', 'Chueca, Madrid', 'Cala Ratjada', 'Chicago', 'London', 'Oakland', 'Calvià', 'Chueca', 'villa verde bajo', 'Torrenova', 'San Diego', "Port d'Andratx", 'Illetes', 'Balearic Islands', 'Muro (Mallorca)', 'Colonia Sant Pere', 'Petra', 'Wien', 'Vienna', 'Cala Pi', 'Biniamar', 'Pina, Mallorca', 'Cologny', 'Can Pastilla', 'Queens', 'Llucalcari', 'Aravaca (Madrid)', 'Cala Magrana', 'Illes Balears', 'La Habana', 'Bondi', 'Seattle', 'Madrid, Comunidad de Madrid, ESPANA', 'Brunswick', 'Montreal', 'Hong Kong', 'Queenscliff', 'Brent', 'Maioris Decima', 'Centro, Madrid', 'Binissalem-Mallorca DO', 'Madri', 'Ginebra', 'Westmount', 'Valldemossa', 'Font de Sa Cala', 'Boadilla del Monte', '马德里', 'Santa Maria del Camí', 'Son Vida', 'Santa Margalida', 'Port de Soller', 'Santa Monica', 'Sol de Mallorca', 'Los Angeles', 'Manchester', 'Sa Coma', 'Porto Cristo', 'Edinburgh', 'Malaga', 'Beverly Hills', 'Sencelles', 'Londres', 'Richmond', 'Sant Llorenç des Cardassar', 'Vancouver', 'Peguera', 'Rotes Velles', 'Los Angeles County', 'Deyá', 'Málaga', 'La Puebla', 'Pina', 'San Fernando de Henares', 'Saint-Gilles', 'Manly', 'Costa dels Pins', 'Sa Garriga', 'Potts Point', 'Vilafranca de Bonany', 'North Bondi', 'Kimmage', 'Brooklyn', 'Cala Santanyí', 'Son Moll', 'Amsterdam', 'Comunidad de Madrid', '馬德里', 'Son Servera', 'St Peters', 'Salerno', 'El Toro', 'Provensals', 'Andratx', 'Saint-Josse-ten-Noode', 'Cala Anguila-Cala Mendia', 'Búger', 'Chelsea, London', 'Bruxelles', 'Alaró', 'Ses Salines', 'Santa Ponsa', 'Malibu', 'Bunyola', 'Mascot', 'Melbourne', 'Coogee', 'Schaerbeek', 'Algaida', 'Frederiksberg', 'Forest Lodge', 'Nashville', 'Palma de Mallorca', 'Bronx', 'Binissalem', 'San Francisco', 'las matas  madrid', 'Sutton', 'South Yarra', 'Forest', 'Barcelona', 'Topanga', 'Windsor', 'Madrid, Vallecas (Fontarrón)', 'Son Veri Nou , Llucmajor', 'Palma', 'Northcote', 'Betlem', 'París', 'Alcúdia', 'Bondi Beach', 'Ventas', 'Athina', 'Venezia', 'Footscray', 'Llucmajor', 'Can Picafort', 'Costitx', 'Ballsbridge', 'Selva', 'Llubí', 'Felanitx', 'Pozuelo', 'Puerto Pollensa (Palma de Mallorca)', 'Newtown', 'Genève', 'Edimburgo', 'Centro', 'Cala Agulla', 'Copenhagen', 'Berlin', 'Austin', 'Sint-Gillis', 'Sa Colònia', 'Muro', 'Bondi Junction', 'Lido', 'Pozuelo de Alarcón', 'Washington', 'Deià', 'Berlín', 'Campos', 'Ariany', 'Lloret de Vistalegre', 'Berowra Waters', 'Dublin', 'Mancor de la Vall', 'Campanet', 'Antwerpen', 'Woolloomooloo', 'Port de Sóller', 'Mile End / Bow', 'Mal Pas-Bon Aire', 'Sóller', 'Rosebery', 'Frederiksberg C', 'Colònia de Sant Jordi', 'Long Beach', 'Boston', 'Lloseta', 'Denver', 'Paris', 'Pollensa', 'Etterbeek', 'Onil', 'Peguera, Calvià', 'Colonia de Sant Pere', 'North Sydney', 'Puerto ALCUDIA', 'Sant Joan', 'Toronto', 'Sa Pobla', 'Playas de Muro', 'Albert Park', 'Marrickville', 'Ixelles', 'Portals Nous', 'Lewisham', 'Chiva', 'Alcudia', 'Inca', 'Roma', 'Manacor', 'Madrid, Comunidad de Madrid, ES', 'Valderrodrigo', 'madrid', 'Madrid', 'Hospitalet de Llobregat', 'Athens', 'Santanyí', 'Montréal', 'Paddington', 'New York', 'Templeogue', 'Port de Pollença', 'Greater London', 'MADRID', 'Aravaca', 'Enmore', 'Sineu', 'Surry Hills', 'New Orleans', 'Pollença', 'Pasadena', 'Urbanització Montferrutx', 'Delicias-Madrid', 'Clongriffin', 'West Hollywood', 'Magaluf', 'Motilla del Palancar', 'Porreres', 'København', 'Rome', 'Cala Murada', 'Cala Ferrera', 'San Fernando', 'Vallgornera', 'Brussel'}

# %%
df_airbnb_madrid_= df_airbnb_madrid.replace(np.nan, 0)

# %%
import psycopg2

from sqlalchemy import create_engine
engine = create_engine('postgresql://gaby:@localhost:5432/proyecto_final')
df_airbnb_madrid_.to_sql('airbnb_list', engine)
# Out:
# 207
